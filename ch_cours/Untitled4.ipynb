# %%
##Projet de programmation PSY4016 - Traitement de données en neuroscience cognitive

# %%
#Importer la base de données
import pandas as pd
df = pd.read_spss(r"C:\Users\Dylan\Desktop\Honor\APES\ACE_COMBINED_Oct2020.sav")
df.head()
# Out:
#         UID   Sex   Age  Height  Weight   IMC    Group          Origine  \
# 0  ACE-0044  Male  38.0    1.70   74.00  25.6  Control            Arabe
# 1  ACE-0087  Male  26.0    1.87     NaN   NaN  Control            Blanc
# 2  ACE-0023  Male  38.0    1.80   86.18  26.6      ACE            Blanc
# 3  ACE-0082  Male  22.0    1.96   84.00  21.9      ACE             Noir
# 4  ACE-0045  Male  28.0    1.81   73.00  22.3      ACE  Amérique latine
#
#   Revenu_individuel       Revenu_fam  ... Age_OC_Bi TIME_Réveil  TIME_30min  \
# 0   25 000 - 50 000  25 000 - 50 000  ...       NaN         NaN         NaN
# 1         0 - 25000        0 - 25000  ...       NaN    09:53:00     37540.0
# 2         0 - 25000        0 - 25000  ...       NaN    06:36:00     26560.0
# 3         0 - 25000        0 - 25000  ...       NaN    07:40:00     29400.0
# 4         0 - 25000        0 - 25000  ...       NaN    07:30:40     29040.0
#
# ...
