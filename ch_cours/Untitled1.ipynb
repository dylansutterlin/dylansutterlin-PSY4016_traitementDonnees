# %%
##cours 1
PYTHON:
    import 
    import ... as ...
    from ... import ... as ...
    from ... import #appuyer TAB
    help()
    len()
    input()
    type()
    sorted()
    
OS:
    import os
    os.chdir()
    os.getcwd()

PANDAS:
    read_csv, read_excel, read_table, read_json,
    df.to_csv, to_excel, to_json, to_pickle
    df.columns
    df.index
    df.COLUMN_NAME
    df["COLUMN_NAME"]
    df['COLUMN_NAME']

# %%
##cours 2
PseudoCode langage humain
PseudoCode format python

STRINGS:
    str()
    ''
    ""
    ''.replace()
    ''.split()

INTEGER / FLOAT
    int()
    float()

LIST:
    []
    list()
    ls.remove()
    ls.append()
    ls.pop
    ls.sort()
    ls.reverse

TUPLE:
    ()
    tuple()

DICTIONARY:
    dict()
    {}
    d[key]
    d[key] = val
    d.keys()
    d.values()
    d.items()
    d.copy()
    d.deepcopy()
    d.get(cle)
    d.pop()
    del d[cle]
    d.clear()
    list(d.keys())

COPY
    copy.deepcopy(d)

PANDAS:
    import pandas
    pandas.DataFrame(source, index=[]) ##source = dict, ls, ou même tuple
 ##permet de spécifier le nom des row et col. Peut mettre une var (ls) comme index
    pandas.DataFrame.from_dict(dict(),
                                orient = 'index',
                                columns = ['A','B','C','D'])
    pandas.read_csv(fichier,
                    usecols = ['COL1', 'COL2'])
    df.keys()
    df.values()
    df.col.tolist()
    df.to_dict()
    df.transpose(), df.T
    df.index
    df.size
    df.shape
    df.ndim
    df.dtype
    df.loc, df.iloc, df.at
    df.copy(deep=True)
    df.set_index(NAME, inplace=True)
    df.head()
    df.tail()

NUMPY:
    np.array(, dtype='float32')
    numpy.asarray(list(), dtype = None)
    numpy.asarray(list(dict().items()), dtype = dict)
    arr0.shape
    arr0.ndim
    np.empty(shape, dtype=int)
    np.zeros(shape, dtype=int)
    np.ones(shape, dtype=float) #shape = [int(), int()]; int()
    np.full()
    np.eye()
    np.repeat
    np.linspace
    np.arange
    np.random; np.random.random; np.random.normal; np.random.randint
    np.reshape
    np.newaxis
    np.where
    np.sort
    np.argsort

INDEXATION []
    chaine.index()
    list.index()
    tuple.index()

# %%
##cours 3
STRINGS:
    ''.replace()
    ''.strip() ! Attention
    ''.rstrip() ! Attention
    ''.split()
    ''.find()
    ''.rfind()
    ''.upper()
    ''.lower()
    ''.isdigit()
    ''.isupper()
    ''.islower()
    ''.endswith()
    ''.startswith()
    ''.count()
    ''.join()
    ''.zfill()
    https://docs.python.org/3/library/stdtypes.html
    https://www.programiz.com/python-programming/methods/string
    
LIST:
    ls.remove()
    ls.append()
    ls.pop
    ls.sort()
    ls.reverse
    ls+ls
    https://docs.python.org/3/library/stdtypes.html

TUPLE:
    tup+tup
    https://docs.python.org/3/library/stdtypes.html

DICTIONARY:
    d.copy()
    d.deepcopy()
    d.get(cle)
    d.pop()
    del d[cle]
    d.clear()

COPY
    copy.deepcopy(d)

PANDAS:
    df.loc, df.iloc, df.at
    df.copy(deep=True)
    df.set_index(NAME, inplace=True)
    df.describe()
    COMBINAISON:
        df_A.append(df_B)
        pandas.concat([df_A, df_B], keys=['rouge','bleue'], axis=0, sort=True)
        df_A.merge(df_B)
        df_A.join(df_B.set_index('name'), on='name')
    GROUPBY:
        df.groupby('COL').mean()
        df.distance[df.COL=='VAL'].mean()
        df.groupby('COL')['COL2'].describe().unstack()
        df.groupby(['COL' , decade])['COL1'].sum().unstack().fillna(0)
NUMPY:
    np.reshape
    np.newaxis
    np.sort
    np.argsort
    np.concatenate
    np.vstack
    np.hstack
    np.split
    np.vsplit
    np.hsplit

   
OPÉRATEURS:
    == != < > <= >=
    and or not
    is, is not
    in, not in
    & |
    astype()
    PANDAS:
        df[df.COL > int]
        df.loc[df.COL > int, ['COL1', 'COL2']].head()
        dfc[(dfc.COL>int) & (df.COL<int]
        count, first, last, mean, median, min, max, sum, std, var, mad, prod
        mean(), add(), sub(), substract(), mul(), multiply(), div(), divide()
        df.COL.mean()
        df['COL'] = df_qc['COL1'].subtract(df_qc['COL2'])
        NAN:
            isnull, notnull, dropna, fillna
            isnull().values.any()
    NUMPY:
        np.min
        np.max
        np.sum
        np.mean
        np.std
        np.any
        np.all
        np.percentile
        np.add
        np.subtract
        np.negative
        np.multiply
        np.divide
